# %% [markdown]
# <a href="https://colab.research.google.com/github/thwjdstar/weather/blob/main/weather.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/데이터분석/data/statisticsDivision_20231123151658.csv', encoding='cp949')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/데이터분석/data/statisticsDivision_20231123151658.csv', encoding='cp949')
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File ~\anaconda3\Lib\site-packages\pandas\io\common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/Colab Notebooks/데이터분석/data/statisticsDivision_20231123151658.csv'

# %%
df

# %%
df['일시'].nunique()

# %%
df['강수량(mm)'].mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df['강수량(mm)'].mean()
#
# NameError: name 'df' is not defined

# %%
df.isna().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df.isna().sum()
#
# NameError: name 'df' is not defined

# %%
df['최고기온 평균(℃)'].max()
# Out:
# 33.3

# %%
df['최저기온 평균(℃)'].max()
# Out:
# 25.2

# %%
df['최저기온 평균(℃)'] == df['최저기온 평균(℃)'].max()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 127    False
# 128    False
# 129    False
# 130    False
# 131    False
# Name: 최저기온 평균(℃), Length: 132, dtype: bool

# %%
df.groupby('일시')['강수량(mm)'].agg([np.sum, np.min])
# Out:
#             sum   amin
# 일시
#  2013-01   22.1   22.1
#  2013-02   74.1   74.1
#  2013-03   27.3   27.3
#  2013-04   71.7   71.7
#  2013-05  132.0  132.0
# ...         ...    ...
#  2023-08  298.1  298.1
#  2023-09  134.5  134.5
#  2023-10   31.0   31.0
#  2023-11   69.8   69.8
#  평균       103.2  103.2
#
# [132 rows x 2 columns]

# %%
df[df['일시'].str.contains('2013')]
# Out:
#           일시  평균기온(℃)  최고기온 평균(℃)  최저기온 평균(℃)  강수량(mm)
# 0    2013-01     -3.4         0.3        -6.6     22.1
# 1    2013-02     -1.2         2.8        -4.9     74.1
# 2    2013-03      5.1        10.8         0.7     27.3
# 3    2013-04     10.0        15.0         5.7     71.7
# 4    2013-05     18.2        23.6        13.7    132.0
# 5    2013-06     24.4        29.2        20.5     28.3
# 6    2013-07     25.5        28.3        23.4    676.2
# 7    2013-08     27.7        31.1        24.8    148.6
# 8    2013-09     21.8        25.9        18.0    138.5
# 9    2013-10     15.8        21.2        10.9     13.5
# 10   2013-11      6.2        10.7         2.1     46.8
# 11   2013-12     -0.2         3.5        -3.5     24.7

# %%
df[df['일시'].str.contains('2014')]
# Out:
#           일시  평균기온(℃)  최고기온 평균(℃)  최저기온 평균(℃)  강수량(mm)
# 12   2014-01     -0.7         3.5        -4.9     13.0
# 13   2014-02      1.9         6.6        -1.8     16.2
# 14   2014-03      7.9        13.1         3.5      7.2
# 15   2014-04     14.0        19.6         9.4     31.0
# 16   2014-05     18.9        25.3        13.8     63.0
# 17   2014-06     23.1        27.8        19.7     98.1
# 18   2014-07     26.1        30.6        22.9    207.9
# 19   2014-08     25.2        29.0        22.1    172.8
# 20   2014-09     22.1        27.0        18.0     88.1
# 21   2014-10     15.6        21.4        10.7     52.2
# 22   2014-11      9.0        13.8         4.9     41.5
# 23   2014-12     -2.9         1.5        -6.7     17.9

# %%
df = df.fillna(0)

# %%
df.describe()
# Out:
#           평균기온(℃)  최고기온 평균(℃)  최저기온 평균(℃)     강수량(mm)
# count  132.000000  132.000000  132.000000  132.000000
# mean    13.372727   18.181061    9.312121  103.196970
# std     10.122638   10.112136   10.278073  126.942402
# min     -4.000000    0.000000   -7.300000    0.000000
# 25%      4.500000    9.850000    0.525000   23.525000
# 50%     14.250000   19.850000    9.550000   62.700000
# 75%     22.875000   27.625000   18.900000  132.625000
# max     28.800000   33.300000   25.200000  676.200000

# %%
plt.hist(data=df,x='평균기온(℃)', rwidth=0.8)
plt.show()

# %%
sb.color_palette()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 sb.color_palette()
#
# NameError: name 'sb' is not defined

# %%
base_order =df['평균기온(℃)'].value_counts().index

# %%
df
# Out:
#            일시  평균기온(℃)  최고기온 평균(℃)  최저기온 평균(℃)  강수량(mm)
# 0     2013-01     -3.4         0.3        -6.6     22.1
# 1     2013-02     -1.2         2.8        -4.9     74.1
# 2     2013-03      5.1        10.8         0.7     27.3
# 3     2013-04     10.0        15.0         5.7     71.7
# 4     2013-05     18.2        23.6        13.7    132.0
# ..        ...      ...         ...         ...      ...
# 127   2023-08     27.2        30.8        24.3    298.1
# 128   2023-09     23.7        27.6        20.2    134.5
# 129   2023-10     15.8        21.0        11.5     31.0
# 130   2023-11      0.0         0.0         0.0     69.8
# 131        평균     13.5        18.3         9.4    103.2
#
# [132 rows x 5 columns]

# %%
plt.scatter(data=df, x='평균기온(℃)', y='강수량(mm)')

plt.title('평균기온(℃) Vs 강수량(mm)')

plt.xlabel('average temperature')

plt.ylabel('precipitation')

plt.show()

# %%
plt.hist(data=df,x='강수량(mm)', rwidth=0.8)
plt.show()

# %%
df['강수량(mm)'].mean()
# Out:
# 103.1969696969697

# %%
df_corr = df.corr(numeric_only=True)

# %%
df_corr
# Out:
#              평균기온(℃)  최고기온 평균(℃)  최저기온 평균(℃)   강수량(mm)
# 평균기온(℃)     1.000000    0.996349    0.997146  0.592762
# 최고기온 평균(℃)  0.996349    1.000000    0.987366  0.551543
# 최저기온 평균(℃)  0.997146    0.987366    1.000000  0.625464
# 강수량(mm)     0.592762    0.551543    0.625464  1.000000

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined
